# %% [markdown]
# #### LetsGrowMore(LGMVIP)- "DATA SCIENCE INTERN "
# #### LGMVIP April-23
# #### AUTHOR - SHWETA KULKARNI
# #### BEGINNER LEVEL TASK

# %% [markdown]
# #### Task1--Iris Flowers Classification

# %%
# Import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading Data
data=pd.read_csv("Iris.csv")

# %%
# First five rows
data.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  target
# 0           0           5.1          3.5           1.4          0.2       0
# 1           1           4.9          3.0           1.4          0.2       0
# 2           2           4.7          3.2           1.3          0.2       0
# 3           3           4.6          3.1           1.5          0.2       0
# 4           4           5.0          3.6           1.4          0.2       0

# %%
# Last five rows
data.tail()
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  target
# 145         145           6.7          3.0           5.2          2.3       2
# 146         146           6.3          2.5           5.0          1.9       2
# 147         147           6.5          3.0           5.2          2.0       2
# 148         148           6.2          3.4           5.4          2.3       2
# 149         149           5.9          3.0           5.1          1.8       2

# %%
# columns in data
data.columns
# Out:
# Index(['Unnamed: 0', 'sepal_length', 'sepal_width', 'petal_length',
#        'petal_width', 'target'],
#       dtype='object')

# %%
# shape of data
data.shape
# Out:
# (150, 6)

# %% [markdown]
# * In this data contain 150 observations & 6 columns .

# %%
# statistics of data
data.describe()
# Out:
#        Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    74.500000      5.843333     3.054000      3.758667     1.198667
# std     43.445368      0.828066     0.433594      1.764420     0.763161
# min      0.000000      4.300000     2.000000      1.000000     0.100000
# 25%     37.250000      5.100000     2.800000      1.600000     0.300000
# 50%     74.500000      5.800000     3.000000      4.350000     1.300000
# 75%    111.750000      6.400000     3.300000      5.100000     1.800000
# max    149.000000      7.900000     4.400000      6.900000     2.500000
#
#            target
# count  150.000000
# mean     1.000000
# std      0.819232
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
# Information of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    150 non-null    int64
#  1   sepal_length  150 non-null    float64
#  2   sepal_width   150 non-null    float64
#  3   petal_length  150 non-null    float64
#  4   petal_width   150 non-null    float64
#  5   target        150 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 7.2 KB

# %%
# check any null values
data.isnull().sum()
# Out:
# Unnamed: 0      0
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# target          0
# dtype: int64

# %%
# check covariance 
data.cov()
# Out:
#                Unnamed: 0  sepal_length  sepal_width  petal_length  \
# Unnamed: 0    1887.500000     25.782886    -7.492282     67.667785
# sepal_length    25.782886      0.685694    -0.039268      1.273682
# sepal_width     -7.492282     -0.039268     0.188004     -0.321713
# petal_length    67.667785      1.273682    -0.321713      3.113179
# petal_width     29.832215      0.516904    -0.117981      1.296387
# target          33.557047      0.530872    -0.148993      1.371812
#
#               petal_width     target
# Unnamed: 0      29.832215  33.557047
# sepal_length     0.516904   0.530872
# sepal_width     -0.117981  -0.148993
# petal_length     1.296387   1.371812
# petal_width      0.582414   0.597987
# target           0.597987   0.671141

# %% [markdown]
# # Exploratory Data Analysis

# %%
data['sepal_length'].hist()
# Out:
# <AxesSubplot:>

# %%
data['sepal_width'].hist()
# Out:
# <AxesSubplot:>

# %%
data['petal_length'].hist()
# Out:
# <AxesSubplot:>

# %%
 data['petal_width'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='sepal_length',y='target',data=data)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='target'>

# %%
sns.scatterplot(x='sepal_width',y='target',data=data)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='target'>

# %%
sns.scatterplot(x='petal_length',y='target',data=data)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='target'>

# %%
sns.scatterplot(x='petal_width',y='target',data=data)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='target'>

# %%
sns.pairplot(data)

# %% [markdown]
# # Data Preprocessing & Feature Engineering

# %%
# Check missing values
data.isnull().sum()
# Out:
# Unnamed: 0      0
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# target          0
# dtype: int64

# %% [markdown]
# * No missing values present.

# %%
# Checking outliers
plt.figure(figsize=(10,15),facecolor='white')
plotnumber=1
for column in data:
    if plotnumber<=10:
        plt.subplot(3,3,plotnumber)
        sns.boxplot(data[column],data=data)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('count',fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# * outliers present in sepal width.

# %% [markdown]
# #### Handling Outliers

# %%
# using Interquantile Range(IQR)
from scipy import stats
IQR = stats.iqr(data.sepal_width,interpolation='midpoint')
IQR
# Out:
# 0.5

# %%
# minimum & maximum limit calculation
# 1st quantile
Q1 = data.sepal_width.quantile(0.25)
# 3rd quantile
Q3 = data.sepal_width.quantile(0.75)
# minimum limit
minimum_limit = Q1-1.5*IQR
# maximum limit
maximum_limit = Q3+1.5*IQR

# %%
print('minimum_limit',minimum_limit)
print('maximum_limit',maximum_limit)
# Out:
# minimum_limit 2.05
# maximum_limit 4.05

# %%
data.loc[data['sepal_width']< minimum_limit]
# Out:
#     Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  target
# 60          60           5.0          2.0           3.5          1.0       1

# %%
data.loc[data['sepal_width']> maximum_limit]
# Out:
#     Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  target
# 15          15           5.7          4.4           1.5          0.4       0
# 32          32           5.2          4.1           1.5          0.1       0
# 33          33           5.5          4.2           1.4          0.2       0

# %%
sns.boxplot(data.sepal_width)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal_width'>

# %% [markdown]
# # Feature Selection

# %%
corr=data.corr()
fig, ax=plt.subplots(figsize=(5,4))
sns.heatmap(corr,annot=True,ax=ax,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
# Remove constant feature
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %% [markdown]
# # Model Creation

# %%
# Creating dependent & independent variable
x =data.drop('target',axis=1)
y=data.target

# %%
# Splitting data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %% [markdown]
# ### Linear Regression

# %%
# Model Selection
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=LR.predict(x_test)
y_predict
# Out:
# array([-0.07242098, -0.10059167,  1.5942698 ,  1.80832357,  1.00452155,
#         1.29523666,  1.10905587,  0.88808907,  0.92100553,  1.16338678,
#         1.68858947, -0.04591563,  2.00327131, -0.02309083,  0.93950892,
#         0.18052257,  2.06599474,  1.98244136,  2.16770258, -0.01809008,
#         1.23822599,  1.73270572,  1.08520658,  1.05653146,  0.04586541,
#        -0.08980617,  1.16093272,  1.75822036,  1.69719964, -0.08930174,
#         1.24373674,  1.67070794,  1.56763696,  1.85931907,  0.01147197,
#         1.76866073,  1.88220136,  1.42920553, -0.00517751,  2.1563945 ,
#         1.15532375,  1.17444542, -0.08930174,  0.03151321, -0.10584743])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
r2score_lr = r2_score(y_test,y_predict)
r2score_lr
# Out:
# 0.935851681316694

# %%
x_test.shape
# Out:
# (45, 4)

# %%
# Calculation of adjusted r2_score
adjusted_r2=1-(1-0.88)*(45-4)/(45-4-1)
adjusted_r2
# Out:
# 0.877

# %%
MSE=print(mean_squared_error(y_test,y_predict))
# Out:
# 0.04263883306060731

# %%
import math

# %%
RMSE=print(math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 0.20649172637325525

# %%
MAE=print(mean_absolute_error(y_test,y_predict))
# Out:
# 0.15531862624699577

# %% [markdown]
# #### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)

# %%
y_pred
# Out:
# array([0., 0., 2., 2., 1., 1., 1., 1., 1., 1., 2., 0., 2., 0., 1., 0., 2.,
#        2., 2., 0., 1., 2., 1., 1., 0., 0., 1., 2., 2., 0., 1., 2., 2., 2.,
#        0., 2., 2., 1., 0., 2., 1., 1., 0., 0., 0.])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
r2score=r2_score(y_test,y_pred)
r2score
# Out:
# 0.9331352154531947

# %%
x_test.shape
# Out:
# (45, 4)

# %%
# Adjusted r2_score
adjusted_r2=1-(1-0.85)*(45-4)/(45-4-1)
adjusted_r2
# Out:
# 0.84625

# %%
MAE=print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.044444444444444446

# %%
MSE=print(mean_squared_error(y_test,y_pred))
# Out:
# 0.044444444444444446

# %%
RMSE=print(math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 0.21081851067789195
